# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = {
    'sqft_area': [600, 750, 900, 1100, 1250, 1400, 1600, 1800, 2000, 2200],
    'price': [2500000, 3200000, 4000000, 4800000, 5500000, 
              6000000, 6800000, 7500000, 8300000, 9000000]
}

df = pd.DataFrame(data)
df
# Out:
#    sqft_area    price
# 0        600  2500000
# 1        750  3200000
# 2        900  4000000
# 3       1100  4800000
# 4       1250  5500000
# 5       1400  6000000
# 6       1600  6800000
# 7       1800  7500000
# 8       2000  8300000
# 9       2200  9000000

# %%
x = df[['sqft_area']]
y = df[['price']]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# user input testing
user_input = eval(input("Enter the area in sqft:"))
predicted_score = model.predict([[user_input]])
predicted_score
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[9882058.77577529]])

# %%
plt.scatter(x,y,label = "Actual data")
plt.plot(x,model.predict(x),color = "red",label= "Predicted Data")
plt.xlabel("Area in Sq-ft")
plt.ylabel("Price")
plt.legend()
plt.show()
